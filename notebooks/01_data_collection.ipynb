# %%
import yfinance as yf
import pandas as pd

# %%
tickers = ["JPM", "BAC", "C", "WFC", "GS"]

# %%
income_statements = {}

for ticker in tickers:
    stock = yf.Ticker(ticker)
    income_statements[ticker] = stock.financials

# %%
income_statements["JPM"]
# Out:
#                                                       2025-12-31  \
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...           NaN
# Reconciled Depreciation                                      NaN
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                            NaN
# Net Income From Continuing And Discontinued Ope...           NaN
# Diluted Average Shares                              2.781500e+09
# Basic Average Shares                                2.776500e+09
# ...

# %%
for ticker, df in income_statements.items():
    df.to_csv(f"../data/raw/{ticker}_income_statement.csv", index=True)

# %%
balance_sheets = {}

for ticker in tickers:
    stock = yf.Ticker(ticker)
    balance_sheets[ticker] = stock.balance_sheet

# %%
for ticker, df in balance_sheets.items():
    df.to_csv(f"../data/raw/{ticker}_balance_sheet.csv", index=True)

# %%
cash_flows={}

for ticker in tickers:
    stock=yf.Ticker(ticker)
    cash_flows[ticker]=stock.cash_flow

# %%
for ticker,df in cash_flows.items():
    df.to_csv(f"../data/raw/{ticker}_cash_flows.csv",index=True)

# %% [markdown]
# Observations:
# - Missing values in early years
# - Different reporting periods
# - Large magnitude values (need scaling)
