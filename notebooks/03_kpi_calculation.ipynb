# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

# %%
from src.kpi_functions import current_ratio, debt_to_equity, return_on_assets

# %%
import pandas as pd

balance = pd.read_csv("../data/processed/JPM_balance_sheet_clean.csv", index_col=0)
income = pd.read_csv("../data/processed/JPM_income_statement_clean.csv", index_col=0)

# %%
balance.columns
# Out:
# Index(['Treasury Shares Number', 'Preferred Shares Number',
#        'Ordinary Shares Number', 'Share Issued', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Net Tangible Assets',
#        'Common Stock Equity', 'Preferred Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Treasury Stock', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Preferred Stock', 'Total Liabilities Net Minority Interest',
#        'Long Term Debt And Capital Lease Obligation', 'Long Term Debt',
#        'Current Debt And Capital Lease Obligation', 'Current Debt',
#        'Other Current Borrowings', 'Payables And Accrued Expenses', 'Payables',
#        'Other Payable', 'Accounts Payable', 'Total Assets',
#        'Investments And Advances', 'Held To Maturity Securities',
# ...

# %%
current_assets = balance["Total Current Assets"]
current_liabilities = balance["Total Current Liabilities"]

total_liabilities = balance["Total Liab"]
total_equity = balance["Total Stockholder Equity"]

net_income = income["Net Income"]
total_assets = balance["Total Assets"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 current_assets = balance["Total Current Assets"]
#       2 current_liabilities = balance["Total Current Liabilities"]
#       4 total_liabilities = balance["Total Liab"]
#
# NameError: name 'balance' is not defined
